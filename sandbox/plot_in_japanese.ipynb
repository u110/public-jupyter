# %%
import seaborn as sns
import matplotlib
font = {'family':'Osaka'} #OS自体に日本語入ってること
matplotlib.rc('font', **font)

import pandas as pd
import numpy as np

# %matplotlib inline

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=list("ABCDE"))
df.plot.box(title=u'あああ')
