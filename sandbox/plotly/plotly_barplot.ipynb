# %% [markdown]
# https://plot.ly/python/getting-started/#initialization-for-offline-plotting

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
import plotly.graph_objs as go

init_notebook_mode(connected=True)
print __version__ # requires version >= 1.9.0
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 1.12.9

# %%
df = pd.DataFrame(np.random.rand(100, 11), columns=list('abcdefghijk'))

# %%
df.describe()
# Out:
#                 a           b           c           d           e           f  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.461493    0.548087    0.495089    0.516510    0.467549    0.501133
# std      0.274155    0.318358    0.283442    0.259399    0.279657    0.295834
# min      0.007790    0.022880    0.043242    0.053642    0.005079    0.011410
# 25%      0.217022    0.260144    0.262433    0.324629    0.250283    0.245230
# 50%      0.475733    0.556098    0.503467    0.511695    0.444278    0.502943
# 75%      0.710855    0.842164    0.742146    0.723637    0.689564    0.705880
# max      0.977794    0.999345    0.977324    0.992688    0.997878    0.989558
#
#                 g           h           i           j           k
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.469963    0.492327    0.526174    0.504841    0.499784
# std      0.300258    0.291524    0.287154    0.283648    0.296546
# ...

# %%
data = [go.Bar(x=df.index.values, y=df[c].values, name=c) for c in df.columns.values]
layout = go.Layout(
    barmode='stack'
)

fig = go.Figure(data=data, layout=layout)
iplot(fig, show_link=False)
# Out:
# <div id="57dc9242-e5cf-4d97-bbf8-1c58c26e7304" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("57dc9242-e5cf-4d97-bbf8-1c58c26e7304", [{"y": [0.5180852585654634, 0.21897338959443802, 0.14010968869919704, 0.5617686502172448, 0.5000639317626366, 0.3136892130273946, 0.6838189270497975, 0.2111674791605731, 0.8048373694543697, 0.4783623089668577, 0.7446616145028243, 0.5625558324660856, 0.5480476149040897, 0.5614765715901258, 0.34435619695128505, 0.5251893182208172, 0.9777944925008083, 0.17272745736945516, 0.6673661925818051, 0.6693001961622833, 0.28974881783823536, 0.06038475101656382, 0.7462202228872472, 0.4002365954399151, 0.3160625650863498, 0.759040884183057, 0.07977257289030504, 0.5348150563915399, 0.00779003741331874, 0.5955591518403165, 0.30759508943061376, 0.6271836668030308, 0.6316858500192459,
# ...
